# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_name = ('/content/drive/MyDrive/Clean_data.xlsx')

# %%
df = pd.read_excel(file_name)

# %%
df
# Out:
#            Date Company_name  Revenues_from_Business_Activties  \
# 0    31-12-2000          EDF                          34424.00
# 1    31-12-2001          EDF                          40716.00
# 2    31-12-2002          EDF                          48359.00
# 3    31-12-2003          EDF                          44919.00
# 4    31-12-2004          EDF                          46788.00
# ..          ...          ...                               ...
# 501  31-12-2017     DASSAULT                           3228.01
# 502  31-12-2018     DASSAULT                           3477.40
# 503  31-12-2019     DASSAULT                           4018.20
# 504  31-12-2020     DASSAULT                           4452.20
# 505  31-12-2021     DASSAULT                           4860.10
#
#      Operating_Profit  Income_Before_Taxes  Net_Income_After_Tax  \
# 0             9919.00              1111.00               1083.00
# 1            11035.00              1216.00                639.00
# 2            12903.00              1376.00                390.00
# 3            12212.00              2476.00                909.00
# 4            11571.00              1580.00                508.00
# ..                ...                  ...                   ...
# 501            758.94               751.42                520.14
# 502            806.60               783.80                563.40
# 503            846.80               815.90                606.30
# 504            726.50               646.30                485.50
# 505           1051.20              1004.30                773.90
#
#      Income_Available_to_Common_Shares
# 0                               759.00
# 1                               840.00
# 2                               481.00
# 3                               857.00
# 4                               624.00
# ..                                 ...
# 501                             519.41
# 502                             569.40
# 503                             615.30
# 504                             491.00
# 505                             773.70
#
# [506 rows x 7 columns]

# %%
#Show the first three values
df.head(3)
# Out:
#          Date Company_name  Revenues_from_Business_Activties  \
# 0  31-12-2000          EDF                           34424.0
# 1  31-12-2001          EDF                           40716.0
# 2  31-12-2002          EDF                           48359.0
#
#    Operating_Profit  Income_Before_Taxes  Net_Income_After_Tax  \
# 0            9919.0               1111.0                1083.0
# 1           11035.0               1216.0                 639.0
# 2           12903.0               1376.0                 390.0
#
#    Income_Available_to_Common_Shares
# 0                              759.0
# 1                              840.0
# 2                              481.0

# %%
df.columns
# Out:
# Index(['Date', 'Company_name', 'Revenues_from_Business_Activties',
#        'Operating_Profit', 'Income_Before_Taxes', 'Net_Income_After_Tax',
#        'Income_Available_to_Common_Shares'],
#       dtype='object')

# %%
#Select the relevant columns
columns_to_select = ['Date','Company_name', 'Revenues_from_Business_Activties', 'Income_Available_to_Common_Shares']

# %%
df_simple = df[columns_to_select]

# %%
#Define the columns to select and their new names
column_rename_dict = {'Revenues_from_Business_Activties': 'Revenue', 
                      'Income_Available_to_Common_Shares': 'Net Income'}

# %%
df_simple = df_simple.rename(columns = column_rename_dict)

# %%
df_simple.describe()
# Out:
#              Revenue    Net Income
# count     506.000000    506.000000
# mean    33193.214763   2273.115632
# std     36582.436238   5842.230296
# min       407.700000 -14764.000000
# 25%     10271.250000    303.352500
# 50%     18556.500000   1067.900000
# 75%     41657.000000   2807.750000
# max    182248.620000  72040.000000

# %%
df_simple.head(5)
# Out:
#          Date Company_name  Revenue  Net Income
# 0  31-12-2000          EDF  34424.0       759.0
# 1  31-12-2001          EDF  40716.0       840.0
# 2  31-12-2002          EDF  48359.0       481.0
# 3  31-12-2003          EDF  44919.0       857.0
# 4  31-12-2004          EDF  46788.0       624.0

# %%
#Select a specific data range
start_date = '31-12-2003'
end_date = '31-12-2013'

# %%
df_date = df_simple[(df_simple.Date >= start_date)&(df_simple.Date <= end_date)]

# %%
#Print the cleaned database with only the required columns and data range
df_date
# Out:
#            Date Company_name   Revenue  Net Income
# 3    31-12-2003          EDF  44919.00      857.00
# 4    31-12-2004          EDF  46788.00      624.00
# 5    31-12-2005          EDF  51047.00     3230.00
# 6    31-12-2006          EDF  58932.00     5605.00
# 7    31-12-2007          EDF  59637.00     5618.00
# ..          ...          ...       ...         ...
# 493  31-12-2009     DASSAULT   1251.34      169.74
# 494  31-12-2010     DASSAULT   1563.84      220.54
# 495  31-12-2011     DASSAULT   1783.04      289.18
# 496  31-12-2012     DASSAULT   2028.34      334.82
# 497  31-12-2013     DASSAULT   2066.12      352.28
#
# [253 rows x 4 columns]

# %%
#Net Income calculation
columns_to_select = ['Net Income','Company_name']

# %%
df_end = df_date[df_date.Date==end_date]

# %%
df_end
# Out:
#            Date      Company_name    Revenue  Net Income
# 13   31-12-2013               EDF   71916.00     3414.00
# 35   31-12-2013            Veolia   22819.70     -170.00
# 57   31-12-2013             TOTAL  171690.49     8456.15
# 79   31-12-2013       AIR_LIQUIDE   15225.20     1640.30
# 101  31-12-2013               BNP   36235.00     4566.00
# 123  31-12-2013   CREDIT_AGRICOLE   15439.00     2510.00
# 145  31-12-2013               AXA  125671.00     4198.00
# 167  31-12-2013  SOCIETE_GENERALE   20785.00     1709.00
# 189  31-12-2013        STELLANTIS   84530.00      904.00
# 211  31-12-2013           RENAULT   40932.00      586.00
# 233  31-12-2013          MICHELIN   20247.00     1120.00
# 255  31-12-2013              LVMH   29016.00     3436.00
# 277  31-12-2013           L_OREAL   22124.20     2958.20
# 299  31-12-2013            HERMES    3754.80      790.30
# 321  31-12-2013            KERING    9655.70       49.60
# 343  31-12-2013            DANONE   21298.00     1422.00
# 365  31-12-2013         BONDUELLE    1896.15       52.09
# 387  31-12-2013    FLEURY-MICHON      697.93       16.23
# 409  31-12-2013         CARREFOUR   76675.00     1263.00
# 431  31-12-2013         CAPGEMINI   10092.00      442.00
# 453  31-12-2013            SAFRAN   14158.00     1386.00
# 475  31-12-2013            THALES   12697.60      573.40
# 497  31-12-2013          DASSAULT    2066.12      352.28

# %%
df_start = df_date[df_date.Date==start_date]

# %%
df_start
# Out:
#            Date      Company_name    Revenue  Net Income
# 3    31-12-2003               EDF   44919.00      857.00
# 25   31-12-2003            Veolia   28603.00    -1826.90
# 47   31-12-2003             TOTAL  104608.05     7022.05
# 69   31-12-2003       AIR_LIQUIDE    8442.10      725.60
# 91   31-12-2003               BNP   18312.00     3761.00
# 113  31-12-2003   CREDIT_AGRICOLE    9004.00     1026.00
# 135  31-12-2003               AXA   98884.00     3673.00
# 157  31-12-2003  SOCIETE_GENERALE   15161.00     2492.00
# 179  31-12-2003        STELLANTIS   50035.00    -2869.00
# 201  31-12-2003           RENAULT   37525.00     2480.00
# 223  31-12-2003          MICHELIN   15946.44      560.70
# 245  31-12-2003              LVMH   11962.00     1023.00
# 267  31-12-2003           L_OREAL   14029.10     2057.70
# 289  31-12-2003            HERMES    1230.00      216.80
# 311  31-12-2003            KERING   24360.80      782.80
# 333  31-12-2003            DANONE   13131.00      923.00
# 355  31-12-2003         BONDUELLE    1318.16       61.37
# 377  31-12-2003    FLEURY-MICHON      605.59       12.49
# 399  31-12-2003         CARREFOUR   70486.20     1629.10
# 421  31-12-2003         CAPGEMINI    5754.00     -197.00
# 443  31-12-2003            SAFRAN    3180.44      119.71
# 465  31-12-2003            THALES   10569.40      211.20
# 487  31-12-2003          DASSAULT     754.82      114.10

# %%
columns_to_take = ['Net Income', 'Company_name']
df_end = df_date[df_date.Date==end_date][columns_to_take].set_index('Company_name')
df_start = df_date[df_date.Date==start_date][columns_to_take].set_index('Company_name')

# %%
df_start
# Out:
#                   Net Income
# Company_name
# EDF                   857.00
# Veolia              -1826.90
# TOTAL                7022.05
# AIR_LIQUIDE           725.60
# BNP                  3761.00
# CREDIT_AGRICOLE      1026.00
# AXA                  3673.00
# SOCIETE_GENERALE     2492.00
# STELLANTIS          -2869.00
# RENAULT              2480.00
# MICHELIN              560.70
# LVMH                 1023.00
# L_OREAL              2057.70
# HERMES                216.80
# KERING                782.80
# DANONE                923.00
# BONDUELLE              61.37
# FLEURY-MICHON          12.49
# CARREFOUR            1629.10
# CAPGEMINI            -197.00
# SAFRAN                119.71
# THALES                211.20
# DASSAULT              114.10

# %%
#Evolution calculation
df_evolution = (df_end - df_start) / df_start

# %%
# plot the data
color = ['g' if value > 0 else 'r' for value in df_evolution['Net Income']]
plt.figure(figsize=(16,10))
plt.bar(df_evolution.index, df_evolution['Net Income'], color=color)
plt.xticks(rotation=45, ha='right');

# %%
file_name = ('/content/drive/MyDrive/Python_Ratios .xlsx')

# %%
df = pd.read_excel(file_name)

# %%
df
# Out:
#    Company name        Date      OPOA  EV_on_EBITDA  \
# 0           EDF  31-12-2003  0.046515          5.14
# 1        VEOLIA  31-12-2003  0.044987          3.77
# 2         TOTAL  31-12-2003  0.143324          6.41
# 3   AIR LIQUIDE  31-12-2003  0.112260          7.91
# 4           BNP  31-12-2003  0.007878          7.48
# ..          ...         ...       ...           ...
# 64    CARREFOUR  31-12-2013  0.051409          8.22
# 65    CAPGEMINI  31-12-2013  0.077634          6.99
# 66       SAFRAN  31-12-2013  0.053718         11.43
# 67       THALES  31-12-2013  0.050291          6.62
# 68     DASSAULT  31-12-2013  0.121722         15.31
#
#                            Industry
# 0                            Energy
# 1                            Energy
# 2                            Energy
# 3                            Energy
# 4    Banking_and_Financial_Services
# ..                              ...
# 64  Consumer_Goods_and_Distribution
# 65           Technology_and_Defense
# 66           Technology_and_Defense
# 67           Technology_and_Defense
# 68           Technology_and_Defense
#
# [69 rows x 5 columns]

# %%
df.groupby(by='Industry').mean()
# Out:
#                                      OPOA  EV_on_EBITDA
# Industry
# Automotive                       0.106041     10.655556
# Banking_and_Financial_Services   0.009142     27.043333
# Consumer_Goods_and_Distribution  0.071509      7.506667
# Energy                           0.082302      6.357500
# Luxury_Goods                     0.132130     14.390000
# Technology_and_Defense           0.050685     11.693333

# %%
df.groupby(by='Date').mean()
# Out:
#                 OPOA  EV_on_EBITDA
# Date
# 31-12-2003  0.086148     12.064783
# 31-12-2008  0.066373     16.098696
# 31-12-2013  0.069374     10.957826

# %%
df_table = df.groupby(by=['Date','Industry']).mean()

# %%
df_table
# Out:
#                                                 OPOA  EV_on_EBITDA
# Date       Industry
# 31-12-2003 Automotive                       0.227534     20.073333
#            Banking_and_Financial_Services   0.006103      3.777500
#            Consumer_Goods_and_Distribution  0.085535      7.052500
#            Energy                           0.086771      5.807500
#            Luxury_Goods                     0.122182     17.742500
#            Technology_and_Defense           0.024111     19.937500
# 31-12-2008 Automotive                       0.037559      6.430000
#            Banking_and_Financial_Services   0.018389     57.867500
#            Consumer_Goods_and_Distribution  0.068411      7.157500
#            Energy                           0.094401      6.487500
#            Luxury_Goods                     0.120170     11.177500
#            Technology_and_Defense           0.052103      5.055000
# 31-12-2013 Automotive                       0.053032      5.463333
#            Banking_and_Financial_Services   0.002933     19.485000
#            Consumer_Goods_and_Distribution  0.060580      8.310000
#            Energy                           0.065733      6.777500
#            Luxury_Goods                     0.154038     14.250000
#            Technology_and_Defense           0.075841     10.087500

# %%
#Graph of OPOA for 2003
df_OPOA_2003 = df_table.loc['31-12-2003']['OPOA']

# %%
df_OPOA_2003
# Out:
# Industry
# Automotive                         0.227534
# Banking_and_Financial_Services     0.006103
# Consumer_Goods_and_Distribution    0.085535
# Energy                             0.086771
# Luxury_Goods                       0.122182
# Technology_and_Defense             0.024111
# Name: OPOA, dtype: float64
# Industry
# Automotive                         0.227534
# Banking_and_Financial_Services     0.006103
# Consumer_Goods_and_Distribution    0.085535
# Energy                             0.086771
# Luxury_Goods                       0.122182
# Technology_and_Defense             0.024111
# Name: OPOA, dtype: float64

# %%
#Plot OPOA in 2003
plt.figure(figsize=(10,10))
df_OPOA_2003.plot()
my_plot = df_OPOA_2003.plot(title='OPOA 2003', color="pink")
plt.xticks(rotation=45, ha='right');

# %% [markdown]
# Interpretation.....

# %%
def min_max(dataframe):
  Maximum = dataframe.idxmax()
  Minimum = dataframe.idxmin()
  text = f'The maximum sector is: {Maximum} \nThe minimum sector is: {Minimum}'
  return text

# %%
print(min_max(df_OPOA_2003))
# Out:
# The maximum sector is: Automotive
# The minimum sector is: Banking_and_Financial_Services
